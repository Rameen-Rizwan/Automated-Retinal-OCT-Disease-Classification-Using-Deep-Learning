# %%
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input # type: ignore
import numpy as np
import os

# %%
model = tf.keras.models.load_model("Trained_Model.keras")

# %%
img_path = './test/DRUSEN/DRUSEN-1112835-7.jpeg'
img = tf.keras.utils.load_img(img_path, target_size=(160, 160))
x = tf.keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
x.shape
# Out:
# (1, 160, 160, 3)

# %%
preds = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
preds
# Out:
# array([[0.22469601, 0.19557332, 0.4575457 , 0.12218492]], dtype=float32)

# %%
class_name = os.listdir("./test")
class_name
# Out:
# ['CNV', 'DME', 'DRUSEN', 'NORMAL']

# %%
result_index = np.argmax(preds)
class_name[result_index]
# Out:
# 'DRUSEN'
